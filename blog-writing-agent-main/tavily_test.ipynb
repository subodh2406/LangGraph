# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# [{'title': 'ChatGPT — Release Notes - OpenAI Help Center',
#   'url': 'https://help.openai.com/en/articles/6825453-chatgpt-release-notes',
#   'content': "January 29, 2026\n   Retiring GPT-4o and other legacy models\n   January 26, 2026\n   Improvements to search response quality in Voice\n   January 22, 2026\n   5.2 Personality System Prompt Update\n   January 20, 2026\n   Voice Updates\n   Rolling out age prediction\n   January 15, 2026\n   Improved memory for finding details from past chats (Plus & Pro)\n   January 12, 2026\n   Dictation Updates\n   January 7, 2026\n   Health in ChatGPT\n   December 22, 2025\n   Your Year with ChatGPT\n   December 19, 2025\n   New detailed characteristic controls\n   December 18, 2025\n   Introducing the app directory in ChatGPT\n   Pinned chats in ChatGPT\n   December 17, 2025\n   Tasks are now in Pulse\n   December 16, 2025\n   ChatGPT Images on Web and Mobile (iOS & Android)\n   December 11, 2025 [...] Image 24: Image\n\nNov 22, 2024\n\nUpdates to the ChatGPT Web experience\n\nWe are rolling out the following updates over the next two weeks to all ChatGPT users.\n\n### Sidebar redesign\n\n   New floating mode added with soft dismiss behavior\n\n   Recent conversations are now limited in the sidebar, with an unlimited infinite scroll flyout for all conversations\n\n   Recent GPTs & Pinned GPT's are now displayed below conversations\n\n   Settings are now always in the bottom of the sidebar\n\n   A small settings icon was added in larger viewports when the sidebar is not open\n\n   New transitions were added to create a more immersive feel\n\n### Other updates for ChatGPT on Web\n\n   The core underpinnings of the site were revamped, offering much better support for a larger variety of devices and sizes [...] Smarter problem-solving in STEM and coding:\n   Enhanced instruction-following and formatting accuracy:\n   “Fuzzy” improvements:\n   March 18, 2025\n   Web and the Windows desktop app\n   Android App\n   iOS App\n   February 28, 2025\n   February 21, 2025\n   February 14, 2025\n   February 6, 2025\n   Canvas sharing\n   January 17, 2025\n   More personalization in Custom Instructions\n   January 15, 2025\n   Import from Chat into Canvas\n   January 14, 2025\n   Scheduled tasks in ChatGPT\n   December 13, 2024\n   Projects in ChatGPT\n   Dec 12, 2024\n   Santa Voice and Video and Screen Share in Voice Chats\n   Dec 10, 2024\n   Canvas\n   Nov 22, 2024\n   Updates to the ChatGPT Web experience\n   Sidebar redesign\n   Other updates for ChatGPT on Web\n   Improved Mobile Web Experience\n   Nov 19, 2024",
#   'score': 0.94401723},
#  {'title': 'ChatGPT by OpenAI - Release Notes - January 2026 Latest Updates',
#   'url': 'https://releasebot.io/updates/openai/chatgpt',
#   'content': 'Our data Browse feeds Sign in Create account\n\n# ChatGPT Release Notes\n\nLast updated: Jan 23, 2026\n\nRSS  Email  API  Slack  n8n  Zapier\n\n Jan 22, 2026 \n  + Date parsed from source:\n\n    Jan 22, 2026\n  + First seen by Releasebot:\n\n    Jan 23, 2026\n  + Modified by Releasebot:\n\n    Jan 25, 2026\n\n  ChatGPT by OpenAI\n\n  ## January 22, 2026\n\n  ### 5.2 Personality System Prompt Update\n\n  We’re updating GPT-5.2 Instant’s default personality to be more conversational and better at adapting its tone contextually, making exchanges feel smoother and more natural. You can still select a different base style and tone for ChatGPT, along with tuning characteristics like warmth and emoji use, within the Personalization menu in settings. [...] Jan 15, 2026\n  + First seen by Releasebot:\n\n    Jan 16, 2026\n\n  ChatGPT by OpenAI\n\n  ## January 15, 2026\n\n  ### Improved memory for finding details from past chats (Plus & Pro)\n\n  When reference chat history is enabled, ChatGPT can now more reliably find specific details from your past chats when you ask. Any past chat used to answer your question now appears as a source so you can open and review the original context.\n\n  This memory improvement is now available for Plus and Pro users globally.\n\n  Original source  Report a problem\n Get an email with every OpenAI release\n\n  Join Releasebot and get updates from OpenAI and hundreds of other software vendors.\n\n  Create account\n\n  Subscribe with:  RSS  Email  API  Slack  n8n  Zapier\n Jan 12, 2026 \n  + Date parsed from source: [...] Jan 12, 2026\n  + First seen by Releasebot:\n\n    Jan 13, 2026\n  + Modified by Releasebot:\n\n    Jan 25, 2026\n\n  ChatGPT by OpenAI\n\n  ## January 12, 2026\n\n  ### Dictation Updates\n\n  We’re improving our dictation capabilities in ChatGPT for all logged-in users, significantly reducing empty transcriptions and improving accuracy.\n\n  Original source  Report a problem\n Jan 7, 2026 \n  + Date parsed from source:\n\n    Jan 7, 2026\n  + First seen by Releasebot:\n\n    Jan 7, 2026\n\n  ChatGPT by OpenAI\n\n  ## January 7, 2026\n\n  ChatGPT launches a Health space for health and wellness chats, letting users securely connect medical records and apps while keeping data separate from core models. Early access for a small group; web and iOS available now, Android coming soon to supported plans.',
#   'score': 0.94326943}]

# %%
for r in results:
    print(r['content'])
# Out:
# January 29, 2026
#    Retiring GPT-4o and other legacy models
#    January 26, 2026
#    Improvements to search response quality in Voice
#    January 22, 2026
#    5.2 Personality System Prompt Update
#    January 20, 2026
#    Voice Updates
#    Rolling out age prediction
#    January 15, 2026
#    Improved memory for finding details from past chats (Plus & Pro)
#    January 12, 2026
#    Dictation Updates
#    January 7, 2026
#    Health in ChatGPT
#    December 22, 2025
#    Your Year with ChatGPT
#    December 19, 2025
#    New detailed characteristic controls
#    December 18, 2025
#    Introducing the app directory in ChatGPT
#    Pinned chats in ChatGPT
#    December 17, 2025
#    Tasks are now in Pulse
#    December 16, 2025
#    ChatGPT Images on Web and Mobile (iOS & Android)
#    December 11, 2025 [...] Image 24: Image
#
# Nov 22, 2024
#
# Updates to the ChatGPT Web experience
#
# We are rolling out the following updates over the next two weeks to all ChatGPT users.
#
# ### Sidebar redesign
#
#    New floating mode added with soft dismiss behavior
#
#    Recent conversations are now limited in the sidebar, with an unlimited infinite scroll flyout for all conversations
#
#    Recent GPTs & Pinned GPT's are now displayed below conversations
#
#    Settings are now always in the bottom of the sidebar
#
#    A small settings icon was added in larger viewports when the sidebar is not open
#
#    New transitions were added to create a more immersive feel
#
# ### Other updates for ChatGPT on Web
#
#    The core underpinnings of the site were revamped, offering much better support for a larger variety of devices and sizes [...] Smarter problem-solving in STEM and coding:
#    Enhanced instruction-following and formatting accuracy:
#    “Fuzzy” improvements:
#    March 18, 2025
#    Web and the Windows desktop app
#    Android App
#    iOS App
#    February 28, 2025
#    February 21, 2025
#    February 14, 2025
#    February 6, 2025
#    Canvas sharing
#    January 17, 2025
#    More personalization in Custom Instructions
#    January 15, 2025
#    Import from Chat into Canvas
#    January 14, 2025
#    Scheduled tasks in ChatGPT
#    December 13, 2024
#    Projects in ChatGPT
#    Dec 12, 2024
#    Santa Voice and Video and Screen Share in Voice Chats
#    Dec 10, 2024
#    Canvas
#    Nov 22, 2024
#    Updates to the ChatGPT Web experience
#    Sidebar redesign
#    Other updates for ChatGPT on Web
#    Improved Mobile Web Experience
#    Nov 19, 2024
# Our data Browse feeds Sign in Create account
#
# # ChatGPT Release Notes
#
# Last updated: Jan 23, 2026
#
# RSS  Email  API  Slack  n8n  Zapier
#
#  Jan 22, 2026
#   + Date parsed from source:
#
#     Jan 22, 2026
#   + First seen by Releasebot:
#
#     Jan 23, 2026
#   + Modified by Releasebot:
#
#     Jan 25, 2026
#
#   ChatGPT by OpenAI
#
#   ## January 22, 2026
#
#   ### 5.2 Personality System Prompt Update
#
#   We’re updating GPT-5.2 Instant’s default personality to be more conversational and better at adapting its tone contextually, making exchanges feel smoother and more natural. You can still select a different base style and tone for ChatGPT, along with tuning characteristics like warmth and emoji use, within the Personalization menu in settings. [...] Jan 15, 2026
#   + First seen by Releasebot:
#
#     Jan 16, 2026
#
#   ChatGPT by OpenAI
#
#   ## January 15, 2026
#
#   ### Improved memory for finding details from past chats (Plus & Pro)
#
#   When reference chat history is enabled, ChatGPT can now more reliably find specific details from your past chats when you ask. Any past chat used to answer your question now appears as a source so you can open and review the original context.
#
#   This memory improvement is now available for Plus and Pro users globally.
#
#   Original source  Report a problem
#  Get an email with every OpenAI release
#
#   Join Releasebot and get updates from OpenAI and hundreds of other software vendors.
#
#   Create account
#
#   Subscribe with:  RSS  Email  API  Slack  n8n  Zapier
#  Jan 12, 2026
#   + Date parsed from source: [...] Jan 12, 2026
#   + First seen by Releasebot:
#
#     Jan 13, 2026
#   + Modified by Releasebot:
#
#     Jan 25, 2026
#
#   ChatGPT by OpenAI
#
#   ## January 12, 2026
#
#   ### Dictation Updates
#
#   We’re improving our dictation capabilities in ChatGPT for all logged-in users, significantly reducing empty transcriptions and improving accuracy.
#
#   Original source  Report a problem
#  Jan 7, 2026
#   + Date parsed from source:
#
#     Jan 7, 2026
#   + First seen by Releasebot:
#
#     Jan 7, 2026
#
#   ChatGPT by OpenAI
#
#   ## January 7, 2026
#
#   ChatGPT launches a Health space for health and wellness chats, letting users securely connect medical records and apps while keeping data separate from core models. Early access for a small group; web and iOS available now, Android coming soon to supported plans.
